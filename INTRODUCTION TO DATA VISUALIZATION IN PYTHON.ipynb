# %% [markdown]
# BASIC DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# load the dataset

df = pd.read_csv(r"C:\Users\COISA COMPUTERS\OneDrive\Documents\PyTHON\student_marks.csv")
df.head(5)
# Out:
#    Subject  Marks
# 0     Math     85
# 1  English     78
# 2  Science     92
# 3  History     74
# 4      Art     65

# %%
#1 use a bargraph to visualize perfomance per subject

plt.bar(df["Subject"], df["Marks"], color= 'red')
plt.title("Student marks per subject")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# 2 Line Chart
#
# Line charts show trends over time (or ordered categories).
# Let’s pretend these are marks across tests:

# %%
tests = ["Test1", "Test2", "Test3", "Test4", "Test5"]
marks = [65, 70, 80, 85, 90]



plt.plot(tests, marks, marker="o", color="yellow")
plt.title("Performance Over Tests")
plt.xlabel("Tests")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# 3 Histogram:Histograms show the distribution of continuous data.
# Let’s simulate marks for 50 students in Math.

# %%
np.random.seed(42)
math_marks = np.random.normal(70, 10, 50)  # mean=70, std=10
print(math_marks)

plt.hist(math_marks, bins=10, color="orange", edgecolor="black")
plt.title("Distribution of Math Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()
# Out:
# [74.96714153 68.61735699 76.47688538 85.23029856 67.65846625 67.65863043
#  85.79212816 77.67434729 65.30525614 75.42560044 65.36582307 65.34270246
#  72.41962272 50.86719755 52.75082167 64.37712471 59.8716888  73.14247333
#  60.91975924 55.87696299 84.65648769 67.742237   70.67528205 55.75251814
#  64.55617275 71.1092259  58.49006423 73.75698018 63.9936131  67.0830625
#  63.98293388 88.52278185 69.86502775 59.42289071 78.22544912 57.7915635
#  72.08863595 50.40329876 56.71813951 71.96861236 77.3846658  71.71368281
#  68.84351718 66.98896304 55.2147801  62.80155792 65.39361229 80.57122226
#  73.4361829  52.36959845]

# %% [markdown]
# 4 Pie Chart
#
# Pie charts show proportions

# %%
plt.pie(df["Marks"], labels=df["Subject"], autopct="%1.1f%%", startangle=140)
plt.title("Percentage of Marks by Subject")
plt.show()

# %% [markdown]
# 5 Donut Chart

# %%
plt.pie(df["Marks"], labels=df["Subject"], autopct="%1.1f%%", startangle=140)
# Add circle for donut effect
centre_circle = plt.Circle((0,0),0.70,fc="white")
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title("Donut Chart of Marks by Subject")
plt.show()

# %% [markdown]
# Data Visualization with Seaborn

# %%
import seaborn as sns

# %%
# bar plot to visualize the student marks

sns.barplot(x= "Subject", y= "Marks", data= df, palette="viridis")
plt.title("Student Marks by Subject (seaborn)")
plt.show()
# Out:
# C:\Users\COISA COMPUTERS\AppData\Local\Temp\ipykernel_14240\674822062.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= "Subject", y= "Marks", data= df, palette="viridis")

# %% [markdown]
# Line Plot

# %%
sns.lineplot(x=tests, y=marks, marker="o", color="red")
plt.title("Performance Over Tests (Seaborn)")
plt.show()

# %% [markdown]
# Histogram / KDE Plot

# %%
sns.histplot(math_marks, bins=10, kde=True, color="purple")
plt.title("Distribution of Math Marks (Seaborn)")
plt.show()
